# %%
# Exercicio 4 
import numpy as np # importa a biblioteca numpy
from sklearn.linear_model import LinearRegression # da biblioteca sklearn importa o modelo de regressao linear
import matplotlib.pyplot as plt

# %%
renda = np.array([1200,5000,8000,10000,30000]).reshape(-1,1)
gastos = np.array ([750,1500,4000,6000,18000]).reshape(-1,1)
modelo = LinearRegression()
            modelo.fit(renda,gastos)
# Out:
# LinearRegression()

# %%
renda_teste = np.array([1500,6500,9500,15000,45000]).reshape(-1,1)
gastos_previstos = modelo.predict(renda_teste)

# %%
for i in range(len(renda_teste)): #Laço de repetição para exibir os dados de saida
    print(f"Renda: {renda_teste[i][0]} Gastos previsto:{gastos_previstos[i][0]:.2f}")
    #gráfico de pontos -scatter
plt.scatter(renda,gastos, color='blue' , label='Dados de Treinamento')
    #gráfico de linhas
plt.plot(renda_teste,gastos_previstos, color = 'red', label='Teste')
plt.xlabel('Renda (R$)')
plt.ylabel('Gastos (R$)')
plt.title('Previsão de gastos a partir da renda.')
plt.legend()
plt.grid(True)
plt.show
# Out:
# Renda: 1500 Gastos previsto:246.49
# Renda: 6500 Gastos previsto:3353.29
# Renda: 9500 Gastos previsto:5217.38
# Renda: 15000 Gastos previsto:8634.86
# Renda: 45000 Gastos previsto:27275.70
# <function matplotlib.pyplot.show(close=None, block=None)>
