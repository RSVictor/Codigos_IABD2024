# %%
# Exercicio 2 
import numpy as np # importa a biblioteca numpy
from sklearn.linear_model import LinearRegression # da biblioteca sklearn importa o modelo de regressao linear
import matplotlib.pyplot as plt

# %%
qnt=  np.array([0,100,200,300,400,500,600,700]).reshape(-1,1)
temp = np.array([0,30,35,40,45,60,100,150]).reshape(-1,1)
modelo = LinearRegression()
modelo.fit(qnt,temp)
# Out:
# LinearRegression()

# %%
qnt_teste = np.array([90,190,307,440,510,602,690]).reshape(-1, 1)
temp_prevista= modelo.predict(qnt_teste)

# %%
for i in range(len(qnt_teste)): 
    print(f"Calor: {qnt_teste[i][0]} Temperatura prevista:{temp_prevista[i]} °C")
    #gráfico de pontos -scatter
plt.scatter(qnt,temp, color='blue' , label='Dados de Treinamento')
    #gráfico de linhas
plt.plot(qnt_teste,temp_prevista, color = 'red', label='Teste')
plt.xlabel('Quantidade Calor')
plt.ylabel('Temperatura ')
plt.title('Previsão de temperatura a partir da Quantidade de calor.')
plt.legend()
plt.grid(True)
plt.show
# Out:
# Calor: 90 Temperatura prevista:[11.69047619] °C
# Calor: 190 Temperatura prevista:[29.30952381] °C
# Calor: 307 Temperatura prevista:[49.92380952] °C
# Calor: 440 Temperatura prevista:[73.35714286] °C
# Calor: 510 Temperatura prevista:[85.69047619] °C
# Calor: 602 Temperatura prevista:[101.9] °C
# Calor: 690 Temperatura prevista:[117.4047619] °C
# <function matplotlib.pyplot.show(close=None, block=None)>
