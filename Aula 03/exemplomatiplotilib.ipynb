# %%
import pandas as pd #importa a biblioteca pandas
import matplotlib.pyplot as plt # importa a biblioteca matplotlib 
import numpy as np # importa a biblioteca numpy

# %%
#Gerando numeros com a numpy
dados_x = np.linspace(0,10,10) #gera valores com a bilblioteca numpy
dados_y = dados_x * dados_x #gera valores multiplicando um dado pelo outro

# %%
plt.figure(figsize=(10,5),facecolor='gray')
Ax = plt.axes() #cria os eixos dos grafico
Ax.set_facecolor('white') #cria o fundo do grafico
plt.xlabel('Eixo X',
           fontweight='bold',#nome do label
           fontsize='large',#estilo
           fontfamily='fantasy',#tamanho da fonte
           color='black',#cor da fonte
           )
plt.ylabel('Eixo Y',
           fontweight='bold',#nome do label
           fontsize='large',#estilo
           fontfamily='fantasy',#tamanho da fonte
           color='black',#cor da fonte
           )
plt.title("Exemplo Matplotlib",
          fontsize=12)#tamnho da fonte
plt.plot(dados_x,dados_y,
         color ='red',linewidth=2,
         marker= 'o',linestyle = 'dashed',markeredgecolor ='black')

# %%
#Grafico 1
plt.rcParams.update({'font.size':15})#define o tamnho da fonte
plt.figure(figsize=(12,12))#define o tamnho da figura
linhas = 2#define o numero de linhas
colunas =2 #define o numero de colunas
plt.subplot(linhas,colunas,1)#define o numero de linhas e colunas
plt.plot(dados_x,'r--')
plt.title("Gráfico 1")
#Grafico 2
plt.subplot(linhas,colunas,2)
plt.plot(dados_x*dados_y,'b-.')
plt.title('Grafico 2')
#Grafico 3
plt.subplot(linhas,colunas,3)
plt.plot(dados_x/2,'c-.')
plt.title("Grafico 3")
#Grafico 4 
plt.subplot(linhas,colunas,4)
plt.plot(dados_y*2, 'r--.')
plt.title("Grafico 4")
plt.savefig("Exemplo subplot.jpg",dp1=300,transparent=True,
            bbox_inches='tight')#comando para salvar a figura
# Out:
# C:\Users\dsadm\AppData\Local\Temp\ipykernel_130652\3024376758.py:21: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dp1" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig("Exemplo subplot.jpg",dp1=300,transparent=True,

# %%
#Grafico de Barras
Figura = plt.figure() #Armazena na variavel Figura a figura a serplotada
Grafico = Figura.add_axes([0,0,0.7,0.7]) #Cria a grade gráfico
Rotulos =['A','B','C','D','E','F','G','H','I','j'] #cria os rotulos
#Gerando o grafico
Grafico.bar(Rotulos,dados_x)
plt.title("Quantidade x Categoria")
plt.xlabel("Itens")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
#Grafico de Barras dentro de outro grafico
Figura = plt.figure() #Armazena na variavel Figura a figura a serplotada
Grafico = Figura.add_axes([0,0,0.7,0.7]) #Cria a grade gráfico
Rotulos =['A','B','C','D','E','F','G','H','I','j'] #cria os rotulos
Grafico.bar(Rotulos,dados_x,color='blue')
Grafico.bar(Rotulos,dados_x*0.1,color='red')
plt.title("Quantidade x Categoria")
plt.xlabel("Itens")
plt.ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')
